# %% [markdown]
# # VGG16 Transfer Learning
#
# Loading the pre-trained VGG16 model, removing the last layer and train with small data set.

# %%
import numpy as np
from keras import layers
from keras.layers import Input, Add, Dense, Activation, ZeroPadding2D, BatchNormalization, Flatten, Conv2D, AveragePooling2D, MaxPooling2D, GlobalMaxPooling2D
from keras.models import Model, load_model
from keras.preprocessing import image
from keras.utils import layer_utils
from keras.utils.data_utils import get_file
from keras.applications.imagenet_utils import preprocess_input
from keras.initializers import glorot_uniform
import matplotlib.pyplot as plt
# %matplotlib inline
import glob

import keras.backend as K
K.set_image_data_format('channels_last')
K.set_learning_phase(1)

from sklearn import decomposition
from sklearn.preprocessing import StandardScaler
# Out:
# Using TensorFlow backend.

# %%
from keras.applications.mobilenet import MobileNet
MobileNet = MobileNet()
MobileNet.summary()
# Out:
# ...
# 17113088/17225924 [============================>.] - ETA: 0s_________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (Activation)      (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# ...

# %%
def evaluate_model(model, X_train, Y_train, X_test, Y_test, maxItem = 100):
    #test model on training data set and testing data set
    nTrain = min([maxItem, X_train.shape[0]])
    print('Performance on Training data set (%d)' % nTrain)
    preds = model.evaluate(X_train[0:nTrain], Y_train[0:nTrain])
    print ("Loss = " + str(preds[0]))
    print ("Train Accuracy = " + str(preds[1]))

    nTest = min([maxItem, X_test.shape[0]])
    print('Performance on Testing data set (%d)' % nTest)
    preds = model.evaluate(X_test[0:nTest], Y_test[0:nTest])
    print ("Loss = " + str(preds[0]))
    print ("Test Accuracy = " + str(preds[1]))

# %% [markdown]
# ## load training and testing data

# %%
selected_classes = ['beaver','pyramid','llama','lotus','crab','car_side']
folderpath = 'C:/projects/computerVision/imageRecognition/Caltech101_Dataset/101_ObjectCategories/'

# %%
def loading_new_dataset(train_pct = 0.8,  classes = selected_classes):
    
    images_data = []
    labels = []
    
    for iclass,class_name in enumerate(classes):
        this_folder = folderpath + class_name
        sub_images = glob.glob(this_folder + '/*')
        for image_path in sub_images:
            print('reading %s with label %s' % (image_path, classes[iclass]))
            img = image.load_img(image_path, target_size=(224, 224))
            x = image.img_to_array(img)
            #x[:,:,0] -= 103.939
            #x[:,:,1] -= 116.779
            #x[:,:,2] -= 123.68
            images_data.append(x)
            labels.append(iclass)
    
    images_data = np.array(images_data)
    labels = np.array(labels)
    
    m = images_data.shape[0]
    permuted_index = np.random.permutation(m)
    split_m = int(np.ceil(m*train_pct))

    train_ind = list(permuted_index[0:split_m])
    test_ind = list(permuted_index[split_m:])

    x_train, y_train = images_data[train_ind], labels[train_ind]
    x_test,  y_test  = images_data[test_ind],  labels[test_ind]
    
    return x_train, y_train, x_test, y_test

# %%
def convert_to_one_hot(Y, C):
    Y = np.eye(C)[Y.reshape(-1)].T
    return Y

# %%
X_train, Y_train, X_test, Y_test = loading_new_dataset(classes = selected_classes)

# Convert training and test labels to one hot matrices
Y_train = convert_to_one_hot(Y_train, len(selected_classes)).T
Y_test = convert_to_one_hot(Y_test, len(selected_classes)).T
# Out:
# reading C:/projects/computerVision/imageRecognition/Caltech101_Dataset/101_ObjectCategories/beaver\image_0001.jpg with label beaver
# reading C:/projects/computerVision/imageRecognition/Caltech101_Dataset/101_ObjectCategories/beaver\image_0002.jpg with label beaver
# reading C:/projects/computerVision/imageRecognition/Caltech101_Dataset/101_ObjectCategories/beaver\image_0003.jpg with label beaver
# reading C:/projects/computerVision/imageRecognition/Caltech101_Dataset/101_ObjectCategories/beaver\image_0004.jpg with label beaver
# reading C:/projects/computerVision/imageRecognition/Caltech101_Dataset/101_ObjectCategories/beaver\image_0005.jpg with label beaver
# reading C:/projects/computerVision/imageRecognition/Caltech101_Dataset/101_ObjectCategories/beaver\image_0006.jpg with label beaver
# reading C:/projects/computerVision/imageRecognition/Caltech101_Dataset/101_ObjectCategories/beaver\image_0007.jpg with label beaver
# ...

# %%
print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 355
# number of test examples = 88
# X_train shape: (355, 224, 224, 3)
# Y_train shape: (355, 6)
# X_test shape: (88, 224, 224, 3)
# Y_test shape: (88, 6)

# %%
for i in range(5):
    plt.figure()
    plt.imshow(X_train[i]/255.)
    plt.title(selected_classes[np.argmax(Y_train[i])])

# %% [markdown]
# ## Add new fianl dense layer, set VGG layers non-trainable

# %%
for layer in MobileNet.layers:
    layer.trainable = False

# %%
X = Dense(len(selected_classes), activation='softmax', name='new_final_layer', kernel_initializer = glorot_uniform(seed=0))(MobileNet.layers[-1].output)

# %%
myMobileNet = Model(input = MobileNet.input, output = X)
# Out:
# C:\Users\xiang.zhai\AppData\Local\Continuum\Miniconda2\envs\ML\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("ne...)`
#   """Entry point for launching an IPython kernel.

# %%
myMobileNet.compile(optimizer = 'adam', loss = 'categorical_crossentropy',metrics = ['accuracy'])

# %%
myMobileNet.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (Activation)      (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (Activation)  (None, 112, 112, 32)      0
# ...

# %%
evaluate_model(myMobileNet, X_train, Y_train, X_test, Y_test, maxItem = 20)
# Out:
# Performance on Training data set (20)
# 20/20 [==============================] - 3s
# Loss = 1.80034327507
# Train Accuracy = 0.0
# Performance on Testing data set (20)
# 20/20 [==============================] - 3s
# Loss = 1.80088543892
# Test Accuracy = 0.10000000149

# %%
featureModel = Model(input = MobileNet.input, output = MobileNet.output)
# Out:
# C:\Users\xiang.zhai\AppData\Local\Continuum\Miniconda2\envs\ML\lib\site-packages\ipykernel_launcher.py:1: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("re...)`
#   """Entry point for launching an IPython kernel.

# %%
nTrain = X_train.shape[0]
nTest = X_test.shape[0]

nFeature = int(featureModel.output.shape[1])

X_train_feature = np.zeros((nTrain, nFeature))
X_test_feature  = np.zeros((nTest, nFeature))

# %%
for i in range(0,nTrain,5):
    iEnd = min([nTrain-1, i+4])
    print('computing features for training data %d - %d' % (i+1, iEnd+1))
    X_train_feature[i:iEnd] = featureModel.predict(X_train[i:iEnd])
# Out:
# computing features for training data 1 - 5
# computing features for training data 6 - 10
# computing features for training data 11 - 15
# computing features for training data 16 - 20
# computing features for training data 21 - 25
# computing features for training data 26 - 30
# computing features for training data 31 - 35
# computing features for training data 36 - 40
# computing features for training data 41 - 45
# computing features for training data 46 - 50
# computing features for training data 51 - 55
# computing features for training data 56 - 60
# computing features for training data 61 - 65
# computing features for training data 66 - 70
# computing features for training data 71 - 75
# computing features for training data 76 - 80
# computing features for training data 81 - 85
# computing features for training data 86 - 90
# computing features for training data 91 - 95
# computing features for training data 96 - 100
# computing features for training data 101 - 105
# ...

# %%
for i in range(0,nTest,5):
    iEnd = min([nTest-1, i+4])
    print('computing features for test data %d - %d' % (i+1, iEnd+1))
    X_test_feature[i:iEnd] = featureModel.predict(X_test[i:iEnd])
# Out:
# computing features for test data 1 - 5
# computing features for test data 6 - 10
# computing features for test data 11 - 15
# computing features for test data 16 - 20
# computing features for test data 21 - 25
# computing features for test data 26 - 30
# computing features for test data 31 - 35
# computing features for test data 36 - 40
# computing features for test data 41 - 45
# computing features for test data 46 - 50
# computing features for test data 51 - 55
# computing features for test data 56 - 60
# computing features for test data 61 - 65
# computing features for test data 66 - 70
# computing features for test data 71 - 75
# computing features for test data 76 - 80
# computing features for test data 81 - 85
# computing features for test data 86 - 88

# %%
pca = decomposition.PCA(n_components = 2)

# %%
x_std = StandardScaler().fit_transform(X_train_feature)
x_feature_pca = pca.fit_transform(x_std)

# %%
Y_train_label = np.argmax(Y_train,axis=1)

# %%
plt.scatter(x_feature_pca[:,0],x_feature_pca[:,1],c=Y_train_label)
plt.title('feature space')

# %% [markdown]
# ### Note:
# Before we do anything, the first 15 layers of VGG16 is already able to distinguage different classes. Here we compute the feature vectors of each training and testing data set, and plot the feature vectors (the first two dimensions in the pca space) colored by their labels. Note that the clusters are decent separated already.

# %%
final_layer_input = Input(shape=(nFeature,))
final_layer_dense = Dense(len(selected_classes), activation='softmax', kernel_initializer = glorot_uniform(seed=0))(final_layer_input)
myMobileNet_patch = Model(inputs = final_layer_input, outputs = final_layer_dense)
myMobileNet_patch.compile(optimizer = 'adam', loss = 'categorical_crossentropy',metrics = ['accuracy'])

# %%
myMobileNet_patch.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         (None, 1000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 6006
# ...
# Total params: 6,006
# Trainable params: 6,006
# Non-trainable params: 0
# _________________________________________________________________

# %%
myMobileNet_patch.fit(X_train_feature, Y_train, epochs = 50, batch_size = 64)
# Out:
# Epoch 1/50
# 355/355 [==============================] - 0s - loss: 1.7665 - acc: 0.3831
# Epoch 2/50
# 355/355 [==============================] - 0s - loss: 1.7614 - acc: 0.3803
# Epoch 3/50
# 355/355 [==============================] - 0s - loss: 1.7563 - acc: 0.3944
# Epoch 4/50
# 355/355 [==============================] - 0s - loss: 1.7513 - acc: 0.4085
# Epoch 5/50
# 355/355 [==============================] - 0s - loss: 1.7463 - acc: 0.4056
# Epoch 6/50
# 355/355 [==============================] - 0s - loss: 1.7412 - acc: 0.4113
# Epoch 7/50
# 355/355 [==============================] - 0s - loss: 1.7365 - acc: 0.4085
# Epoch 8/50
# 355/355 [==============================] - 0s - loss: 1.7316 - acc: 0.4113
# Epoch 9/50
# 355/355 [==============================] - 0s - loss: 1.7266 - acc: 0.4169
# Epoch 10/50
# 355/355 [==============================] - 0s - loss: 1.7217 - acc: 0.4141
# Epoch 11/50
# 355/355 [==============================] - 0s - loss: 1.7171 - acc: 0.4169
# ...

# %%
#the following code will take long time because we are computing the feature vector for each training data repeatedly

#myVGGNet.fit(X_train, Y_train, epochs = 2, batch_size = 32)

# %%
#evaluate_model(myVGGNet, X_train, Y_train, X_test, Y_test, maxItem = 20)

# %%
#prediction_result = myVGGNet.predict(X_test[0:10])
#predicted_labels = np.argmax(prediction_result,axis=1)

# %%
evaluate_model(myMobileNet_patch, X_train_feature, Y_train, X_test_feature, Y_test, maxItem = 1000)
# Out:
# Performance on Training data set (355)
#  32/355 [=>............................] - ETA: 0sLoss = 1.54980601291
# Train Accuracy = 0.490140845154
# Performance on Testing data set (88)
# 32/88 [=========>....................] - ETA: 0sLoss = 1.59895776619
# Test Accuracy = 0.374999998645

# %%
prediction_result = myMobileNet_patch.predict(X_test_feature)
predicted_labels = np.argmax(prediction_result,axis=1)

# %%
for i in range(10):
    actu = np.argmax(Y_test[i])
    plt.figure()
    plt.imshow(X_test[i]/255.)
    plt.title(selected_classes[predicted_labels[i]] + ' ' + selected_classes[actu])

# %%
plot_model(model, to_file='model.png')
SVG(model_to_dot(model).create(prog='dot', format='svg'))
